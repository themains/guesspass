# %%
# !pip install fastprogress
# Out:
# Requirement already satisfied: fastprogress in /usr/local/lib/python3.10/dist-packages (1.0.3)

# %%
import csv
import torch
from torchtext.vocab import build_vocab_from_iterator
from torch.utils.data import DataLoader, Dataset
from torch.nn.utils.rnn import pad_sequence

import pandas as pd

import torch.nn as nn
import torch.optim as optim

import numpy as np
import h5py

from fastprogress import master_bar, progress_bar

# %%
# Custom char tokenizer
def char_tokenizer(text):
    return list(text)

# Yield tokens from dataset for vocabulary building
def yield_tokens(data):
    for src, trg in data:
        yield char_tokenizer(src)
        yield char_tokenizer(trg)

# Load data from CSV
def load_data_from_csv(filename):
    with open(filename, 'r', encoding='utf-8') as file:
        csv_reader = csv.reader(file)
        data = [(row[0], row[1]) for row in csv_reader]
    return data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_data_raw = load_data_from_csv('/content/drive/MyDrive/Colab/password_predict/data/train_100_1m.csv')
val_data_raw = load_data_from_csv('/content/drive/MyDrive/Colab/password_predict/data/val_100_50k.csv')
test_data_raw = load_data_from_csv('/content/drive/MyDrive/Colab/password_predict/data/test_100_50k.csv')

# %%
vocab = build_vocab_from_iterator(yield_tokens(train_data_raw), specials=['<sos>', '<eos>', '<unk>'])
vocab.set_default_index(vocab["<unk>"])

print(f"Vocab length: {len(vocab)}")
# Out:
# Vocab length: 98

# %%
# save vocab
import pickle

with open('/content/drive/MyDrive/Colab/password_predict/data/vocab.pkl', 'wb') as f:
    pickle.dump(vocab, f)

# %%
# Dataset class
class CSVDataset(Dataset):
    def __init__(self, data, vocab):
        self.data = data
        self.vocab = vocab

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        src, trg = self.data[index]
        src = [self.vocab[token] for token in char_tokenizer(src)]
        trg = [self.vocab['<sos>']] + [self.vocab[token] for token in char_tokenizer(trg)]  # prepend <sos>
        return torch.tensor(src), torch.tensor(trg)

# %%
# Padding function
def collate_fn(batch):
    src_batch, trg_batch = zip(*batch)
    src_batch = pad_sequence(src_batch, padding_value=vocab['<eos>'], batch_first=True)
    trg_batch = pad_sequence(trg_batch, padding_value=vocab['<eos>'], batch_first=True)
    return src_batch, trg_batch

# %%
# DataLoader
BATCH_SIZE = 128

train_dataset = CSVDataset(train_data_raw, vocab)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, collate_fn=collate_fn, shuffle=True)

val_dataset = CSVDataset(val_data_raw, vocab)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, collate_fn=collate_fn, shuffle=False)  # Usually, no need to shuffle val/test data

test_dataset = CSVDataset(test_data_raw, vocab)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, collate_fn=collate_fn, shuffle=False)

# %%
# check sample from dataset
for src, trg in train_dataset:
    print(src, trg)
    break
# Out:
# tensor([20, 11,  4,  6,  7,  3, 13,  4]) tensor([ 0, 29,  3, 11, 11])

# %%
# Sample usage:
for src, trg in train_loader:
    # src and trg here are tokenized, batched, and padded sequences
    print(src.shape, trg.shape)
    break
# Out:
# torch.Size([128, 20]) torch.Size([128, 21])

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        self.hid_dim = hid_dim
        self.embedding = nn.Embedding(input_dim, emb_dim)
        self.rnn = nn.LSTM(emb_dim, hid_dim, n_layers, dropout = dropout)
        self.dropout = nn.Dropout(dropout)

    def forward(self, src):
        embedded = self.dropout(self.embedding(src))
        outputs, (hidden, cell) = self.rnn(embedded)
        return hidden, cell

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        self.output_dim = output_dim
        self.hid_dim = hid_dim
        self.embedding = nn.Embedding(output_dim, emb_dim)
        self.rnn = nn.LSTM(emb_dim, hid_dim, n_layers, dropout = dropout)
        self.fc_out = nn.Linear(hid_dim, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, input, hidden, cell):
        input = input.unsqueeze(0)
        embedded = self.dropout(self.embedding(input))
        output, (hidden, cell) = self.rnn(embedded, (hidden, cell))
        prediction = self.fc_out(output.squeeze(0))
        return prediction, hidden, cell

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.device = device

    def forward(self, src, trg, teacher_forcing_ratio=0.5):
        trg_len, batch_size = trg.shape
        trg_vocab_size = self.decoder.output_dim
        outputs = torch.zeros(trg_len, batch_size, trg_vocab_size).to(self.device)
        hidden, cell = self.encoder(src)
        input = trg[0, :]

        for t in range(1, trg_len):
            output, hidden, cell = self.decoder(input, hidden, cell)
            outputs[t] = output
            teacher_force = torch.rand(1) < teacher_forcing_ratio
            top1 = output.argmax(1)
            input = trg[t] if teacher_force else top1

        return outputs

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.min_validation_loss = np.inf

    def early_stop(self, validation_loss):
        if validation_loss < self.min_validation_loss:
            self.min_validation_loss = validation_loss
            self.counter = 0
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
# Assuming src and trg are your tokenized, padded source and target sequences
INPUT_DIM = len(vocab)
OUTPUT_DIM = len(vocab)
ENC_EMB_DIM = 256
DEC_EMB_DIM = 256
HID_DIM = 512
N_LAYERS = 2
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Seq2Seq(enc, dec, device).to(device)

lr = 0.001

optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=60, eta_min=1e-5)
criterion = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=10)

epochs=100

mb = master_bar(range(epochs))
mb.names = ['Training loss', 'Validation loss']

x = []
training_losses = []
validation_losses = []

valid_mean_min = np.Inf

# Training loop
for epoch in mb:
  x.append(epoch)
  total_loss = torch.Tensor([0.0]).to(device)

  # train
  model.train()
  for batch in progress_bar(train_loader, parent=mb):
      src, trg = batch
      src = src.permute(1, 0).to(device).long()
      trg = trg.permute(1, 0).to(device).long()
      optimizer.zero_grad()
      output = model(src, trg)
      output_dim = output.shape[-1]
      output = output[1:].reshape(-1, output_dim)
      trg = trg[1:].reshape(-1)
      loss = criterion(output, trg)
      loss.backward()
      optimizer.step()
      total_loss += loss.item()

  # decay lr
  scheduler.step()
  mean = total_loss / len(train_loader)
  training_losses.append(mean.cpu())

  # validation
  model.eval()
  validation_loss = torch.Tensor([0.0]).to(device)
  with torch.no_grad():
    for batch in progress_bar(val_loader, parent=mb):
      src, trg = batch
      src = src.permute(1, 0).to(device).long()
      trg = trg.permute(1, 0).to(device).long()
      output = model(src, trg)
      output_dim = output.shape[-1]
      output = output[1:].reshape(-1, output_dim)
      trg = trg[1:].reshape(-1)
      loss = criterion(output, trg)
      validation_loss += loss.item()

  val_mean = validation_loss / len(val_loader)
  validation_losses.append(val_mean.cpu())
  mb.update_graph([[x, training_losses], [x, validation_losses]], [0,epochs])
  mb.write(f"\nEpoch {epoch}: Training loss {mean.item():.6f} validation loss {val_mean.item():.6f} with lr {lr:.6f}")

  # save model if validation loss has decreased
  if val_mean.item() <= valid_mean_min:
      print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
      valid_mean_min,
      val_mean.item()))
      torch.save(model.state_dict(), '/content/drive/MyDrive/Colab/password_predict/pass_predict_100_direct_mapping.pt')
      valid_mean_min = val_mean.item()

  if early_stopper.early_stop(val_mean.item()):
    break
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='63' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       63.00% [63/100 5:57:27&lt;3:29:56]
#     </div>
#
#
# Epoch 0: Training loss 1.203600 validation loss 1.159051 with lr 0.001000<p>
# Epoch 1: Training loss 1.158369 validation loss 1.133265 with lr 0.001000<p>
# Epoch 2: Training loss 1.139917 validation loss 1.112159 with lr 0.001000<p>
# Epoch 3: Training loss 1.126104 validation loss 1.110047 with lr 0.001000<p>
# Epoch 4: Training loss 1.119545 validation loss 1.103408 with lr 0.001000<p>
# Epoch 5: Training loss 1.113457 validation loss 1.091354 with lr 0.001000<p>
# Epoch 6: Training loss 1.107125 validation loss 1.092904 with lr 0.001000<p>
# Epoch 7: Training loss 1.104360 validation loss 1.081598 with lr 0.001000<p>
# Epoch 8: Training loss 1.101368 validation loss 1.084964 with lr 0.001000<p>
# Epoch 9: Training loss 1.096804 validation loss 1.080662 with lr 0.001000<p>
# Epoch 10: Training loss 1.095339 validation loss 1.086885 with lr 0.001000<p>
# Epoch 11: Training loss 1.094085 validation loss 1.076267 with lr 0.001000<p>
# Epoch 12: Training loss 1.084136 validation loss 1.074424 with lr 0.001000<p>
# Epoch 13: Training loss 1.088085 validation loss 1.070697 with lr 0.001000<p>
# Epoch 14: Training loss 1.083157 validation loss 1.072379 with lr 0.001000<p>
# Epoch 15: Training loss 1.082105 validation loss 1.069435 with lr 0.001000<p>
# Epoch 16: Training loss 1.081081 validation loss 1.073680 with lr 0.001000<p>
# Epoch 17: Training loss 1.079143 validation loss 1.063316 with lr 0.001000<p>
# Epoch 18: Training loss 1.077848 validation loss 1.068271 with lr 0.001000<p>
# Epoch 19: Training loss 1.075216 validation loss 1.059604 with lr 0.001000<p>
# Epoch 20: Training loss 1.074102 validation loss 1.064975 with lr 0.001000<p>
# Epoch 21: Training loss 1.071163 validation loss 1.062530 with lr 0.001000<p>
# Epoch 22: Training loss 1.071930 validation loss 1.063047 with lr 0.001000<p>
# Epoch 23: Training loss 1.069521 validation loss 1.064068 with lr 0.001000<p>
# Epoch 24: Training loss 1.073523 validation loss 1.062587 with lr 0.001000<p>
# Epoch 25: Training loss 1.068191 validation loss 1.059047 with lr 0.001000<p>
# Epoch 26: Training loss 1.066298 validation loss 1.056666 with lr 0.001000<p>
# Epoch 27: Training loss 1.067690 validation loss 1.059831 with lr 0.001000<p>
# Epoch 28: Training loss 1.065302 validation loss 1.055901 with lr 0.001000<p>
# Epoch 29: Training loss 1.063108 validation loss 1.054505 with lr 0.001000<p>
# Epoch 30: Training loss 1.062464 validation loss 1.054833 with lr 0.001000<p>
# Epoch 31: Training loss 1.060099 validation loss 1.051821 with lr 0.001000<p>
# Epoch 32: Training loss 1.056929 validation loss 1.052525 with lr 0.001000<p>
# Epoch 33: Training loss 1.059363 validation loss 1.055665 with lr 0.001000<p>
# Epoch 34: Training loss 1.057561 validation loss 1.053664 with lr 0.001000<p>
# Epoch 35: Training loss 1.055637 validation loss 1.051120 with lr 0.001000<p>
# Epoch 36: Training loss 1.056294 validation loss 1.053407 with lr 0.001000<p>
# Epoch 37: Training loss 1.054000 validation loss 1.050514 with lr 0.001000<p>
# Epoch 38: Training loss 1.055560 validation loss 1.045097 with lr 0.001000<p>
# Epoch 39: Training loss 1.051452 validation loss 1.046922 with lr 0.001000<p>
# Epoch 40: Training loss 1.051060 validation loss 1.050966 with lr 0.001000<p>
# Epoch 41: Training loss 1.048915 validation loss 1.049084 with lr 0.001000<p>
# Epoch 42: Training loss 1.049865 validation loss 1.051673 with lr 0.001000<p>
# Epoch 43: Training loss 1.047196 validation loss 1.047747 with lr 0.001000<p>
# Epoch 44: Training loss 1.048725 validation loss 1.046088 with lr 0.001000<p>
# Epoch 45: Training loss 1.045676 validation loss 1.048593 with lr 0.001000<p>
# Epoch 46: Training loss 1.048555 validation loss 1.044091 with lr 0.001000<p>
# Epoch 47: Training loss 1.047617 validation loss 1.044370 with lr 0.001000<p>
# Epoch 48: Training loss 1.045241 validation loss 1.040542 with lr 0.001000<p>
# Epoch 49: Training loss 1.046922 validation loss 1.044156 with lr 0.001000<p>
# Epoch 50: Training loss 1.045863 validation loss 1.046043 with lr 0.001000<p>
# Epoch 51: Training loss 1.043829 validation loss 1.042804 with lr 0.001000<p>
# Epoch 52: Training loss 1.047673 validation loss 1.044237 with lr 0.001000<p>
# Epoch 53: Training loss 1.043007 validation loss 1.047313 with lr 0.001000<p>
# Epoch 54: Training loss 1.044713 validation loss 1.039497 with lr 0.001000<p>
# Epoch 55: Training loss 1.042262 validation loss 1.042373 with lr 0.001000<p>
# Epoch 56: Training loss 1.042715 validation loss 1.045747 with lr 0.001000<p>
# Epoch 57: Training loss 1.044021 validation loss 1.043295 with lr 0.001000<p>
# Epoch 58: Training loss 1.045098 validation loss 1.049657 with lr 0.001000<p>
# Epoch 59: Training loss 1.043636 validation loss 1.045685 with lr 0.001000<p>
# Epoch 60: Training loss 1.042671 validation loss 1.045452 with lr 0.001000<p>
# Epoch 61: Training loss 1.041333 validation loss 1.046963 with lr 0.001000<p>
# Epoch 62: Training loss 1.044849 validation loss 1.050390 with lr 0.001000<p>
#
#     <div>
#       <progress value='6549' class='' max='7813' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       83.82% [6549/7813 04:36&lt;00:53]
#     </div>
# /usr/local/lib/python3.10/dist-packages/numpy/core/shape_base.py:65: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   ary = asanyarray(ary)
# Validation loss decreased (inf --> 1.159051).  Saving model ...
# /usr/local/lib/python3.10/dist-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# Validation loss decreased (1.159051 --> 1.133265).  Saving model ...
# Validation loss decreased (1.133265 --> 1.112159).  Saving model ...
# Validation loss decreased (1.112159 --> 1.110047).  Saving model ...
# Validation loss decreased (1.110047 --> 1.103408).  Saving model ...
# Validation loss decreased (1.103408 --> 1.091354).  Saving model ...
# Validation loss decreased (1.091354 --> 1.081598).  Saving model ...
# Validation loss decreased (1.081598 --> 1.080662).  Saving model ...
# Validation loss decreased (1.080662 --> 1.076267).  Saving model ...
# Validation loss decreased (1.076267 --> 1.074424).  Saving model ...
# Validation loss decreased (1.074424 --> 1.070697).  Saving model ...
# Validation loss decreased (1.070697 --> 1.069435).  Saving model ...
# Validation loss decreased (1.069435 --> 1.063316).  Saving model ...
# Validation loss decreased (1.063316 --> 1.059604).  Saving model ...
# Validation loss decreased (1.059604 --> 1.059047).  Saving model ...
# Validation loss decreased (1.059047 --> 1.056666).  Saving model ...
# Validation loss decreased (1.056666 --> 1.055901).  Saving model ...
# Validation loss decreased (1.055901 --> 1.054505).  Saving model ...
# Validation loss decreased (1.054505 --> 1.051821).  Saving model ...
# Validation loss decreased (1.051821 --> 1.051120).  Saving model ...
# Validation loss decreased (1.051120 --> 1.050514).  Saving model ...
# Validation loss decreased (1.050514 --> 1.045097).  Saving model ...
# Validation loss decreased (1.045097 --> 1.044091).  Saving model ...
# Validation loss decreased (1.044091 --> 1.040542).  Saving model ...
# Validation loss decreased (1.040542 --> 1.039497).  Saving model ...
#     <div>
#       <progress value='76' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       76.00% [76/100 7:10:46&lt;2:16:02]
#     </div>
#
#
# Epoch 0: Training loss 1.203600 validation loss 1.159051 with lr 0.001000<p>
# Epoch 1: Training loss 1.158369 validation loss 1.133265 with lr 0.001000<p>
# Epoch 2: Training loss 1.139917 validation loss 1.112159 with lr 0.001000<p>
# Epoch 3: Training loss 1.126104 validation loss 1.110047 with lr 0.001000<p>
# Epoch 4: Training loss 1.119545 validation loss 1.103408 with lr 0.001000<p>
# Epoch 5: Training loss 1.113457 validation loss 1.091354 with lr 0.001000<p>
# Epoch 6: Training loss 1.107125 validation loss 1.092904 with lr 0.001000<p>
# Epoch 7: Training loss 1.104360 validation loss 1.081598 with lr 0.001000<p>
# Epoch 8: Training loss 1.101368 validation loss 1.084964 with lr 0.001000<p>
# Epoch 9: Training loss 1.096804 validation loss 1.080662 with lr 0.001000<p>
# Epoch 10: Training loss 1.095339 validation loss 1.086885 with lr 0.001000<p>
# Epoch 11: Training loss 1.094085 validation loss 1.076267 with lr 0.001000<p>
# Epoch 12: Training loss 1.084136 validation loss 1.074424 with lr 0.001000<p>
# Epoch 13: Training loss 1.088085 validation loss 1.070697 with lr 0.001000<p>
# Epoch 14: Training loss 1.083157 validation loss 1.072379 with lr 0.001000<p>
# Epoch 15: Training loss 1.082105 validation loss 1.069435 with lr 0.001000<p>
# Epoch 16: Training loss 1.081081 validation loss 1.073680 with lr 0.001000<p>
# Epoch 17: Training loss 1.079143 validation loss 1.063316 with lr 0.001000<p>
# Epoch 18: Training loss 1.077848 validation loss 1.068271 with lr 0.001000<p>
# Epoch 19: Training loss 1.075216 validation loss 1.059604 with lr 0.001000<p>
# Epoch 20: Training loss 1.074102 validation loss 1.064975 with lr 0.001000<p>
# Epoch 21: Training loss 1.071163 validation loss 1.062530 with lr 0.001000<p>
# Epoch 22: Training loss 1.071930 validation loss 1.063047 with lr 0.001000<p>
# Epoch 23: Training loss 1.069521 validation loss 1.064068 with lr 0.001000<p>
# Epoch 24: Training loss 1.073523 validation loss 1.062587 with lr 0.001000<p>
# Epoch 25: Training loss 1.068191 validation loss 1.059047 with lr 0.001000<p>
# Epoch 26: Training loss 1.066298 validation loss 1.056666 with lr 0.001000<p>
# Epoch 27: Training loss 1.067690 validation loss 1.059831 with lr 0.001000<p>
# Epoch 28: Training loss 1.065302 validation loss 1.055901 with lr 0.001000<p>
# Epoch 29: Training loss 1.063108 validation loss 1.054505 with lr 0.001000<p>
# Epoch 30: Training loss 1.062464 validation loss 1.054833 with lr 0.001000<p>
# Epoch 31: Training loss 1.060099 validation loss 1.051821 with lr 0.001000<p>
# Epoch 32: Training loss 1.056929 validation loss 1.052525 with lr 0.001000<p>
# Epoch 33: Training loss 1.059363 validation loss 1.055665 with lr 0.001000<p>
# Epoch 34: Training loss 1.057561 validation loss 1.053664 with lr 0.001000<p>
# Epoch 35: Training loss 1.055637 validation loss 1.051120 with lr 0.001000<p>
# Epoch 36: Training loss 1.056294 validation loss 1.053407 with lr 0.001000<p>
# Epoch 37: Training loss 1.054000 validation loss 1.050514 with lr 0.001000<p>
# Epoch 38: Training loss 1.055560 validation loss 1.045097 with lr 0.001000<p>
# Epoch 39: Training loss 1.051452 validation loss 1.046922 with lr 0.001000<p>
# Epoch 40: Training loss 1.051060 validation loss 1.050966 with lr 0.001000<p>
# Epoch 41: Training loss 1.048915 validation loss 1.049084 with lr 0.001000<p>
# Epoch 42: Training loss 1.049865 validation loss 1.051673 with lr 0.001000<p>
# Epoch 43: Training loss 1.047196 validation loss 1.047747 with lr 0.001000<p>
# Epoch 44: Training loss 1.048725 validation loss 1.046088 with lr 0.001000<p>
# Epoch 45: Training loss 1.045676 validation loss 1.048593 with lr 0.001000<p>
# Epoch 46: Training loss 1.048555 validation loss 1.044091 with lr 0.001000<p>
# Epoch 47: Training loss 1.047617 validation loss 1.044370 with lr 0.001000<p>
# Epoch 48: Training loss 1.045241 validation loss 1.040542 with lr 0.001000<p>
# Epoch 49: Training loss 1.046922 validation loss 1.044156 with lr 0.001000<p>
# Epoch 50: Training loss 1.045863 validation loss 1.046043 with lr 0.001000<p>
# Epoch 51: Training loss 1.043829 validation loss 1.042804 with lr 0.001000<p>
# Epoch 52: Training loss 1.047673 validation loss 1.044237 with lr 0.001000<p>
# Epoch 53: Training loss 1.043007 validation loss 1.047313 with lr 0.001000<p>
# Epoch 54: Training loss 1.044713 validation loss 1.039497 with lr 0.001000<p>
# Epoch 55: Training loss 1.042262 validation loss 1.042373 with lr 0.001000<p>
# Epoch 56: Training loss 1.042715 validation loss 1.045747 with lr 0.001000<p>
# Epoch 57: Training loss 1.044021 validation loss 1.043295 with lr 0.001000<p>
# Epoch 58: Training loss 1.045098 validation loss 1.049657 with lr 0.001000<p>
# Epoch 59: Training loss 1.043636 validation loss 1.045685 with lr 0.001000<p>
# Epoch 60: Training loss 1.042671 validation loss 1.045452 with lr 0.001000<p>
# Epoch 61: Training loss 1.041333 validation loss 1.046963 with lr 0.001000<p>
# Epoch 62: Training loss 1.044849 validation loss 1.050390 with lr 0.001000<p>
# Epoch 63: Training loss 1.044796 validation loss 1.048350 with lr 0.001000<p>
# Epoch 64: Training loss 1.040980 validation loss 1.035636 with lr 0.001000<p>
# Epoch 65: Training loss 1.040672 validation loss 1.041286 with lr 0.001000<p>
# Epoch 66: Training loss 1.045144 validation loss 1.035473 with lr 0.001000<p>
# Epoch 67: Training loss 1.041705 validation loss 1.043693 with lr 0.001000<p>
# Epoch 68: Training loss 1.045171 validation loss 1.044092 with lr 0.001000<p>
# Epoch 69: Training loss 1.045060 validation loss 1.045276 with lr 0.001000<p>
# Epoch 70: Training loss 1.043795 validation loss 1.044569 with lr 0.001000<p>
# Epoch 71: Training loss 1.045828 validation loss 1.042643 with lr 0.001000<p>
# Epoch 72: Training loss 1.045019 validation loss 1.037023 with lr 0.001000<p>
# Epoch 73: Training loss 1.042190 validation loss 1.042866 with lr 0.001000<p>
# Epoch 74: Training loss 1.041588 validation loss 1.044256 with lr 0.001000<p>
# Epoch 75: Training loss 1.043687 validation loss 1.038832 with lr 0.001000<p>
#
#     <div>
#       <progress value='391' class='' max='391' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [391/391 00:07&lt;00:00]
#     </div>
# Validation loss decreased (1.039497 --> 1.035636).  Saving model ...
# Validation loss decreased (1.035636 --> 1.035473).  Saving model ...

# %%
INPUT_DIM = len(vocab)
OUTPUT_DIM = len(vocab)
ENC_EMB_DIM = 256
DEC_EMB_DIM = 256
HID_DIM = 512
N_LAYERS = 2
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Seq2Seq(enc, dec, device).to(device)

# %%
model.load_state_dict(torch.load('/content/drive/MyDrive/Colab/password_predict/pass_predict_100_direct_mapping.pt'))
# Out:
# <All keys matched successfully>

# %%
itos = vocab.get_itos()

# %%
itos[0]
# Out:
# '<sos>'

# %%
from nltk.translate.bleu_score import sentence_bleu

model.eval()
total_bleu = 0

with torch.no_grad():
    for src, trg in test_loader:
        src = src.permute(1, 0).to(device).long()
        trg = trg.permute(1, 0).to(device).long()

        # Turn off teacher forcing
        output = model(src, trg, 0)
        output_dim = output.shape[-1]
        output = output[1:].reshape(-1, output_dim)

        # Convert model's outputs to tokens
        predicted_tokens = torch.argmax(output, dim=1)
        predicted_sentence = [itos[tok.item()] for tok in predicted_tokens]

        reference = [itos[tok.item()] for tok in trg[1:].reshape(-1)]
        total_bleu += sentence_bleu([reference], predicted_sentence)

average_bleu = total_bleu / len(test_loader)
print(f'Average BLEU score: {average_bleu:.3f}')
# Out:
# Average BLEU score: 0.724

# %%
def predict(model, vocab, device, src_sentence, n=1):
    model.eval()
    max_seq = 20

    # Convert the source sentence to tokens
    src_tokens = [tok for tok in src_sentence]
    src_indexes = [vocab[tok] for tok in src_tokens] + [vocab['<eos>']]

    # Convert to tensor and add batch dimension
    src_tensor = torch.LongTensor(src_indexes).unsqueeze(1).to(device)

    # Initialize target sequence with <sos> token
    result = []
    for i in range(n):
        trg_indexes = [vocab['<sos>']]
        predicted_sentence = []
        count = 0
        # Predict next token
        while True:
            trg_tensor = torch.LongTensor(trg_indexes).unsqueeze(1).to(device)
            with torch.no_grad():
                output = model(src_tensor, trg_tensor)
                #print(output)
                predicted_token = output.argmax(2)[-1, :].item()
                # Check for end of sentence
                if predicted_token == vocab['<eos>']:
                    break

                # Append the predicted token to the target sequence
                trg_indexes.append(predicted_token)
                # Convert the target sequence to words
                predicted_sentence.append(itos[predicted_token])
                count += 1
                if count > max_seq:
                    break

        # Convert the target sequence to words
        if ''.join(predicted_sentence[1:]) in result:
            continue
        result.append(''.join(predicted_sentence[1:]))

    return result  # Exclude the <sos> token

# %%
# !head -10 /content/drive/MyDrive/Colab/password_predict/data/test_100_50k.csv
# Out:
# username,pass
# nadina,fuckit
# info,giordano
# adambale1981,RASPUTINasd
# mikamalosh,134679852
# buh2,17051960
# andri4y,Danara
# andrea,junglejim22
# oleg272726,zabludshaya
# mak38er,pimp4life

# %%
predict(model, vocab, device, "admin", 100)
# Out:
# ['1a34d566',
#  '123346',
#  '121313',
#  '122313',
#  '1a1420',
#  '121d4a',
#  '121325',
#  '1a14a5',
#  '1a31a5',
#  '1a1nd3',
#  '1a3n2i',
#  '1a1n2e6',
#  '1a32253',
#  '122335',
#  '1a2243',
#  '12n343',
#  '1a3d13',
#  '1224332',
#  '1a3241',
#  '1233e54',
#  '1233233',
#  '122d31',
#  '122345',
#  '123345',
#  '123333',
#  '1a3243',
#  '122333',
#  '1213456',
#  '121323',
#  '1a2n43',
#  '121415',
#  '1a3na1',
#  '121d2a',
#  '1a1d5a',
#  '123425',
#  '1a31a1',
#  '122d46',
#  '1annde',
#  '1a1415',
#  '123343',
#  '123d2e',
#  '1a2d1a2',
#  '1a3n2e3r',
#  '1a2203',
#  '1a3n23',
#  '1a13a3',
#  '12n3dea',
#  '1a3d43',
#  '1233e2',
#  '121413',
#  '12n33t',
#  '123325',
#  '1a3n253',
#  '1a3de3',
#  '1a3nea',
#  '1233e3',
#  '1an1de',
#  '1a1213',
#  '121d11',
#  '1a14a3',
#  '1a2433',
#  '1a3nd3a',
#  '1a3na669',
#  '122343',
#  '1anneia',
#  '1an1d2',
#  '1a1d1a',
#  '12n3er',
#  '1a2n0i0',
#  '1anddea',
#  '121315',
#  '1a12d3',
#  '1an1a2',
#  '12234r6',
#  '122430',
#  '122445',
#  '122433',
#  '1a11a1',
#  '1a23ca',
#  '121445',
#  '1223336',
#  '1ann4e',
#  '1214456',
#  '121316',
#  '12n333',
#  '122132',
#  '1a13d3',
#  '1a3d41',
#  '1a1443',
#  '1an4d3a',
#  '1a3353',
#  '1anndea']

# %%
# !pip install python-Levenshtein
# Out:
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.25.0-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.25.0 (from python-Levenshtein)
#   Downloading Levenshtein-0.25.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 1.8 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=3.1.0 (from Levenshtein==0.25.0->python-Levenshtein)
#   Downloading rapidfuzz-3.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 19.1 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.25.0 python-Levenshtein-0.25.0 rapidfuzz-3.6.1

# %%
from Levenshtein import distance as lev
lev("123456", "123456")
# Out:
# 0

# %%
lev("51234", "123456")
# Out:
# 3

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab/password_predict/data/test_100_50k.csv")
df.head()
# Out:
#        username         pass
# 0        nadina       fuckit
# 1          info     giordano
# 2  adambale1981  RASPUTINasd
# 3    mikamalosh    134679852
# 4          buh2     17051960

# %%
from tqdm.notebook import tqdm
import pandas as pd
# Assuming the predict and lev functions are defined elsewhere

tqdm.pandas()

def avg_and_min_edit_dist(username, actual_pass):
    pred_passes = predict(model, vocab, device, username, 100)
    if not pred_passes:
        return (0, None)  # Return 0 and None if pred_passes is empty

    # Calculate edit distances between actual_pass and each predicted pass
    edit_distances = [lev(actual_pass, pred_pass) for pred_pass in pred_passes]
    avg_edit_dist = sum(edit_distances) / len(pred_passes)
    best_pred_pass = pred_passes[edit_distances.index(min(edit_distances))]
    return (best_pred_pass, avg_edit_dist)

# Sample a subset of the dataframe
temp_df = df.sample(n=10000)

# Apply the function and create two new columns for best predicted password and average edit distance
temp_df[['best_pred_pass', 'avg_edit_dist']] = temp_df.progress_apply(lambda x: pd.Series(avg_and_min_edit_dist(x['username'], x['pass'])), axis=1)

temp_df.sort_values('avg_edit_dist').head(10)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#        username     pass best_pred_pass  avg_edit_dist
# 25337  chyisn59   chyisn         chyisn       1.500000
# 20666    kaban2    kaban          kaban       1.571429
# 47179     fahri    fahri          fahri       2.075000
# 3674    passat2   passat         passat       2.076923
# 25332  mrraen67   mrraen         mrraen       2.173077
# 43945       211     1234            123       2.200000
# 45362      daan   daan11          daan1       2.250000
# 45490       pat     1234           1234       2.301587
# 6642   reindeer  reindee         reinee       2.318182
# 14876      lola     lola           lola       2.333333

# %%
# Assuming temp_df is your DataFrame
sorted_df = temp_df.sort_values('avg_edit_dist')

# Saving the sorted DataFrame to a CSV file
sorted_df.to_csv('/content/drive/MyDrive/Colab/password_predict/data/1m_direct_mapping_results.csv', index=False)  # Adjust the file name as needed
