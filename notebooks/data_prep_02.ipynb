# %%
# !head -10 /content/drive/MyDrive/Colab/password_predict/data/train_100.csv
# Out:
# username,pass
# motto,757575
# fritz,57072
# ag,90427
# alnet,1e6ga4
# lsmith377,106449
# bacchus2,target123q
# lovestory,123456789
# elizaveta_zotova_2015,qweqwe678678641
# lapo4ka,0207

# %%
# getting out of memery, so take 50k from train_sample.csv
# !head -1000000 /content/drive/MyDrive/Colab/password_predict/data/train_100.csv > /content/drive/MyDrive/Colab/password_predict/data/train_100_1m.csv
# take 5k from val_sample.csv
# !head -50000 /content/drive/MyDrive/Colab/password_predict/data/val_100.csv > /content/drive/MyDrive/Colab/password_predict/data/val_100_50k.csv
# take 5k from test_sample.csv
# !head -50000 /content/drive/MyDrive/Colab/password_predict/data/test_100.csv > /content/drive/MyDrive/Colab/password_predict/data/test_100_50k.csv

# %%
# !du -sh /content/drive/MyDrive/Colab/password_predict/data/train_100_1m.csv
# Out:
# 18M	/content/drive/MyDrive/Colab/password_predict/data/train_100_1m.csv

# %%
# !tail -10 /content/drive/MyDrive/Colab/password_predict/data/train_100_1m.csv
# Out:
# annagrin,maron
# jarred,ginger
# kesha1,dragon
# hjadoon1,jadoonz
# joe69,wildfire69
# julie,tnm_finest_young_herb
# adjlaf1,apple11asdq
# xgreg,850girls
# seregalacosta,123124125a123
# voda_2001,123

# %%
# !head -10 /content/drive/MyDrive/Colab/password_predict/data/val_100_50k.csv
# Out:
# username,pass
# adie,123ea081534
# okuchan,einstein
# marcelo,bacchus
# rougeau2,123456789
# jtullis,jbzibziak
# ekaterina_p,EAPAAPNLG
# jackson,tester
# styuha,12341
# bpreston,kqc5a
